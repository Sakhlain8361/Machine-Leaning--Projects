# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\Shaik Sakhlaih\Downloads\apple_sales_2024.csv")
data
# Out:
#          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                             7.46
# 1      Germany         Europe                             8.63
# 2           UK         Europe                             5.61
# 3     Shanghai  Greater China                             7.82
# 4     Thailand   Rest of Asia                            16.70
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                            29.86
# 996      Texas  North America                            27.83
# 997    Germany         Europe                            25.47
# 998   Shenzhen  Greater China                            15.34
# 999   Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                             6.75                          1.19
# 1                            14.06                          7.03
# 2                            14.09                          8.78
# 3                             7.97                          9.78
# 4                             8.13                          6.46
# ..                             ...                           ...
# 995                          10.30                          7.40
# 996                          12.52                          8.89
# 997                           7.69                          7.90
# 998                           8.81                          8.24
# 999                           4.06                          3.41
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 0                            5.88                            15.88
# 1                            7.42                            10.12
# 2                            8.19                            19.85
# 3                            2.28                             6.16
# 4                            3.48                            13.29
# ..                            ...                              ...
# 995                          9.60                            18.56
# 996                          4.46                             6.38
# 997                          6.90                            15.00
# 998                          8.78                            15.49
# 999                          5.69                            14.29
#
# [1000 rows x 7 columns]

# %%
data.head()
# Out:
#        State         Region  iPhone Sales (in million units)  \
# 0  Chongqing  Greater China                             7.46
# 1    Germany         Europe                             8.63
# 2         UK         Europe                             5.61
# 3   Shanghai  Greater China                             7.82
# 4   Thailand   Rest of Asia                            16.70
#
#    iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                           6.75                          1.19
# 1                          14.06                          7.03
# 2                          14.09                          8.78
# 3                           7.97                          9.78
# 4                           8.13                          6.46
#
#    Wearables (in million units)  Services Revenue (in billion $)
# 0                          5.88                            15.88
# 1                          7.42                            10.12
# 2                          8.19                            19.85
# 3                          2.28                             6.16
# 4                          3.48                            13.29

# %%
data.tail()
# Out:
#         State         Region  iPhone Sales (in million units)  \
# 995    Mexico  Rest of World                            29.86
# 996     Texas  North America                            27.83
# 997   Germany         Europe                            25.47
# 998  Shenzhen  Greater China                            15.34
# 999  Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 995                          10.30                          7.40
# 996                          12.52                          8.89
# 997                           7.69                          7.90
# 998                           8.81                          8.24
# 999                           4.06                          3.41
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 995                          9.60                            18.56
# 996                          4.46                             6.38
# 997                          6.90                            15.00
# 998                          8.78                            15.49
# 999                          5.69                            14.29

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State                            1000 non-null   object
#  1   Region                           1000 non-null   object
#  2   iPhone Sales (in million units)  1000 non-null   float64
#  3   iPad Sales (in million units)    1000 non-null   float64
#  4   Mac Sales (in million units)     1000 non-null   float64
#  5   Wearables (in million units)     1000 non-null   float64
#  6   Services Revenue (in billion $)  1000 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 54.8+ KB

# %%
data.describe()
# Out:
#        iPhone Sales (in million units)  iPad Sales (in million units)  \
# count                      1000.000000                    1000.000000
# mean                         17.444500                       8.565880
# std                           7.180077                       3.735994
# min                           5.030000                       2.020000
# 25%                          11.447500                       5.432500
# 50%                          17.130000                       8.695000
# 75%                          23.715000                      11.740000
# max                          29.940000                      14.990000
#
#        Mac Sales (in million units)  Wearables (in million units)  \
# count                   1000.000000                   1000.000000
# mean                       5.555760                      6.935500
# std                        2.506491                      2.951677
# min                        1.010000                      2.000000
# 25%                        3.470000                      4.330000
# 50%                        5.550000                      6.815000
# 75%                        7.730000                      9.532500
# max                        9.990000                     12.000000
#
#        Services Revenue (in billion $)
# count                      1000.000000
# mean                         12.447130
# std                           4.306347
# min                           5.010000
# 25%                           8.710000
# 50%                          12.205000
# 75%                          16.252500
# max                          19.920000

# %%
data.isnull().sum()
# Out:
# State                              0
# Region                             0
# iPhone Sales (in million units)    0
# iPad Sales (in million units)      0
# Mac Sales (in million units)       0
# Wearables (in million units)       0
# Services Revenue (in billion $)    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['State', 'Region', 'iPhone Sales (in million units)',
#        'iPad Sales (in million units)', 'Mac Sales (in million units)',
#        'Wearables (in million units)', 'Services Revenue (in billion $)'],
#       dtype='object')

# %%
data['State'].value_counts()
# Out:
# State
# Hong Kong       50
# UK              47
# California      47
# South Africa    47
# Brazil          46
# Canada          46
# Shanghai        43
# Shenzhen        43
# France          43
# Beijing         43
# Australia       43
# Japan           40
# Chongqing       40
# Mexico          39
# Spain           39
# Indonesia       38
# Italy           38
# Germany         37
# New York        37
# Illinois        35
# South Korea     34
# Thailand        33
# India           33
# Texas           33
# Florida         26
# Name: count, dtype: int64

# %%
data['Region'].value_counts()
# Out:
# Region
# Rest of World    221
# Greater China    219
# Europe           204
# Rest of Asia     178
# North America    178
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['State'] = le.fit_transform(data['State'])
data['Region'] = le.fit_transform(data['Region'])

# %%
data
# Out:
#      State  Region  iPhone Sales (in million units)  \
# 0        5       1                             7.46
# 1        8       0                             8.63
# 2       24       0                             5.61
# 3       17       1                             7.82
# 4       23       3                            16.70
# ..     ...     ...                              ...
# 995     15       4                            29.86
# 996     22       2                            27.83
# 997      8       0                            25.47
# 998     18       1                            15.34
# 999     17       1                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                             6.75                          1.19
# 1                            14.06                          7.03
# 2                            14.09                          8.78
# 3                             7.97                          9.78
# 4                             8.13                          6.46
# ..                             ...                           ...
# 995                          10.30                          7.40
# 996                          12.52                          8.89
# 997                           7.69                          7.90
# 998                           8.81                          8.24
# 999                           4.06                          3.41
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 0                            5.88                            15.88
# 1                            7.42                            10.12
# 2                            8.19                            19.85
# 3                            2.28                             6.16
# 4                            3.48                            13.29
# ..                            ...                              ...
# 995                          9.60                            18.56
# 996                          4.46                             6.38
# 997                          6.90                            15.00
# 998                          8.78                            15.49
# 999                          5.69                            14.29
#
# [1000 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State                            1000 non-null   int64
#  1   Region                           1000 non-null   int64
#  2   iPhone Sales (in million units)  1000 non-null   float64
#  3   iPad Sales (in million units)    1000 non-null   float64
#  4   Mac Sales (in million units)     1000 non-null   float64
#  5   Wearables (in million units)     1000 non-null   float64
#  6   Services Revenue (in billion $)  1000 non-null   float64
# dtypes: float64(5), int64(2)
# memory usage: 54.8 KB

# %%
x = data.drop(['Region'], axis = 1)
y = data['Region']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.3, random_state = 0)
print("x_train",x_train.shape)
print("x_test",x_test.shape)
print("y_train",y_train.shape)
print("y_test",y_test.shape)
# Out:
# x_train (700, 6)
# x_test (300, 6)
# y_train (700,)
# y_test (300,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([2.0105312 , 1.79451092, 1.68161892, 2.15580984, 2.14796051,
#        1.92536776, 2.40507582, 1.7978628 , 2.31075924, 2.19361444,
#        1.43706077, 1.67052673, 1.71592346, 1.49530537, 2.17892019,
#        1.57058393, 2.18747364, 2.11774264, 1.90088935, 2.33541027,
#        2.12811081, 2.16787299, 1.94376512, 1.80543036, 1.83608487,
#        1.58922814, 1.48617692, 1.60872588, 2.075086  , 2.08866795,
#        2.43979559, 1.86426291, 1.50629537, 1.63495891, 1.75038162,
#        1.9006072 , 2.12756973, 1.67532553, 1.88497019, 2.07901822,
#        1.91942444, 1.44840723, 2.33508928, 1.93353784, 2.02550921,
#        1.88675084, 1.71827435, 2.38767743, 2.01607485, 2.24670573,
#        1.67002601, 1.41133563, 1.66925249, 1.88573901, 2.21082581,
#        1.73367101, 1.56176186, 1.54159822, 2.03898842, 2.46643948,
#        1.5621587 , 1.55544966, 2.0640379 , 2.24372447, 2.03723024,
#        2.25061764, 1.88677328, 2.37297469, 1.67458872, 2.33004279,
#        1.92137525, 2.38839616, 1.62463691, 1.75713832, 1.75167751,
#        2.02984056, 1.91420206, 2.00736836, 1.97152651, 2.2635444 ,
#        2.13144842, 2.39058277, 2.49068494, 1.94802121, 2.000735  ,
#        1.96105071, 1.53759451, 2.29013345, 2.36425058, 1.92185363,
#        2.19697564, 1.81400309, 1.51596883, 1.66086414, 1.93815723,
#        2.19692746, 2.09498342, 1.84142631, 1.76449416, 2.35087163,
#        1.76527139, 1.65793107, 1.55405741, 2.3276731 , 2.09699403,
#        2.14229664, 2.30907736, 1.73291929, 2.16293786, 1.77111493,
#        1.76480093, 1.58195997, 2.03161207, 2.25179725, 2.04174521,
#        1.49646689, 1.67202035, 2.26327457, 2.30824396, 2.3415919 ,
#        1.60026294, 2.01987998, 1.6752792 , 1.7082063 , 1.57320779,
#        1.62874694, 1.61574083, 1.86383276, 1.80711193, 2.22396766,
#        2.28521052, 2.0721259 , 2.2387937 , 1.51011548, 1.78304717,
#        1.76096703, 2.03416128, 1.70356003, 2.13953158, 1.58698417,
#        2.0192783 , 1.71906097, 1.83483623, 2.155004  , 2.14546096,
#        2.13925396, 1.44916468, 1.87759471, 1.48867946, 2.15663777,
#        2.20487015, 1.56979291, 1.90197483, 1.70206361, 1.43268676,
#        1.56978733, 2.06297514, 1.52815113, 1.5984286 , 2.38529798,
#        1.57155792, 1.73115095, 1.84203246, 2.39067231, 1.49470976,
#        2.37496789, 2.18105661, 2.24868274, 2.09617781, 2.18262186,
#        1.80510528, 1.74987696, 2.37877283, 2.29406809, 2.46301655,
#        2.20465237, 1.79928241, 1.90346192, 2.11924287, 1.59910563,
#        2.34454995, 1.72198855, 1.82091967, 1.51365446, 2.06756521,
#        1.55505266, 1.82514817, 2.29281911, 2.31865766, 1.74301637,
#        2.2376712 , 2.17345762, 1.92950922, 2.27934356, 1.99559289,
#        2.34183559, 1.59281082, 2.27776529, 2.14124851, 1.94568488,
#        1.6347208 , 1.43011689, 1.83618836, 1.73810928, 2.2702586 ,
#        1.88373841, 1.61335205, 1.86363774, 1.51918081, 2.21273826,
#        2.32676915, 1.82590102, 1.98933172, 1.9151077 , 1.88838131,
#        2.39083075, 2.17589345, 2.18825973, 1.58224417, 2.23150614,
#        1.73800482, 2.30603406, 1.51859978, 2.33978019, 1.89918737,
#        1.66407538, 2.36115372, 1.52865467, 1.83227383, 1.77157154,
#        1.9478038 , 1.62006912, 1.70508265, 1.59862511, 2.20631032,
#        1.61563041, 1.99633544, 1.91749534, 2.25203968, 1.86830604,
#        2.25220507, 2.32095314, 1.49583272, 1.939521  , 1.9891232 ,
#        2.35213625, 1.57099657, 1.61200773, 1.55123271, 2.39515869,
#        1.54899623, 1.6341788 , 1.67016494, 1.50401102, 1.54566626,
#        1.63176334, 1.94269104, 1.98333201, 2.34031311, 1.75573646,
#        1.99179733, 1.68402499, 1.46730987, 1.71348271, 1.85287673,
#        2.13021317, 1.64588536, 1.83698254, 2.09176662, 1.87827226,
#        1.60113126, 2.33028013, 2.14301881, 2.29221061, 1.88930817,
#        1.69414799, 1.57684319, 1.51670287, 2.2324603 , 2.07000783,
#        2.11131671, 2.13102577, 2.16355777, 2.024552  , 2.00913964,
#        2.30483074, 2.09954169, 1.6609943 , 1.54649752, 1.57566163,
#        2.21261221, 2.14744602, 1.62640647, 1.82908599, 1.92931826,
#        1.65558518, 1.77272991, 2.33316182, 1.94900889, 1.9992966 ])

# %%
print("Coefficients :",model.coef_)
print("Intercept :",model.intercept_)
# Out:
# Coefficients : [-0.03648936 -0.00193331  0.00187502 -0.00162183  0.01740497  0.00932282]
# Intercept : 2.158814135796974

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared error :",mse)
# Out:
# Mean Squared error : 2.1449946519935796

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("The r2 score :",r2)
# Out:
# The r2 score : 0.010895198797894468

# %%
error = y_test - y_pred
error
# Out:
# 993    0.989469
# 859    1.205489
# 298    2.318381
# 553    1.844190
# 672   -0.147961
#          ...
# 167   -0.655585
# 998   -0.772730
# 984   -0.333162
# 491    1.050991
# 10    -0.999297
# Name: Region, Length: 300, dtype: float64

# %%
sns.regplot(x = y_pred, y = error, data = data)
# Out:
# <Axes: ylabel='Region'>
